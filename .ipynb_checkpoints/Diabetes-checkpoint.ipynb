# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %%time
df = pd.read_csv('diabetic_data.csv')
# Out:
# CPU times: user 300 ms, sys: 35.6 ms, total: 336 ms
# Wall time: 334 ms

# %%
df.head()
# Out:
#    encounter_id max_glu_serum A1Cresult metformin repaglinide nateglinide  \
# 0       2278392          None      None        No          No          No
# 1        149190          None      None        No          No          No
# 2         64410          None      None        No          No          No
# 3        500364          None      None        No          No          No
# 4         16680          None      None        No          No          No
#
#   chlorpropamide glimepiride acetohexamide glipizide  ... citoglipton insulin  \
# 0             No          No            No        No  ...          No      No
# 1             No          No            No        No  ...          No      Up
# 2             No          No            No    Steady  ...          No      No
# 3             No          No            No        No  ...          No      Up
# 4             No          No            No    Steady  ...          No  Steady
#
# ...

# %%
df.tail()
# Out:
#         encounter_id max_glu_serum A1Cresult metformin repaglinide  \
# 101761     443847548          None        >8    Steady          No
# 101762     443847782          None      None        No          No
# 101763     443854148          None      None    Steady          No
# 101764     443857166          None      None        No          No
# 101765     443867222          None      None        No          No
#
#        nateglinide chlorpropamide glimepiride acetohexamide glipizide  ...  \
# 101761          No             No          No            No        No  ...
# 101762          No             No          No            No        No  ...
# 101763          No             No          No            No        No  ...
# 101764          No             No          No            No    Steady  ...
# 101765          No             No          No            No        No  ...
#
#        citoglipton insulin glyburide-metformin glipizide-metformin  \
# ...

# %%
df.shape
# Out:
# (101766, 29)
